# %% [markdown]
# <a align="center" href="https://ultralytics.com/hub" target="_blank">
# <img width="1024", src="https://github.com/ultralytics/assets/raw/main/im/ultralytics-hub.png"></a>
#
# <div align="center">
#
# [中文](https://docs.ultralytics.com/zh/hub/) | [한국어](https://docs.ultralytics.com/ko/hub/) | [日本語](https://docs.ultralytics.com/ja/hub/) | [Русский](https://docs.ultralytics.com/ru/hub/) | [Deutsch](https://docs.ultralytics.com/de/hub/) | [Français](https://docs.ultralytics.com/fr/hub/) | [Español](https://docs.ultralytics.com/es/hub/) | [Português](https://docs.ultralytics.com/pt/hub/) | [Türkçe](https://docs.ultralytics.com/tr/hub/) | [Tiếng Việt](https://docs.ultralytics.com/vi/hub/) | [العربية](https://docs.ultralytics.com/ar/hub/)
#
#   <a href="https://github.com/ultralytics/hub/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/hub/actions/workflows/ci.yml/badge.svg" alt="CI CPU"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/hub/blob/main/hub.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
# Welcome to the [Ultralytics](https://ultralytics.com/) HUB notebook!
#
# This notebook allows you to train Ultralytics [YOLO](https://github.com/ultralytics/ultralytics) 🚀 models using [HUB](https://hub.ultralytics.com/). Please browse the HUB <a href="https://docs.ultralytics.com/hub/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/hub/issues/new/choose">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# %pip install ultralytics  # install
from ultralytics import YOLO, checks, hub

checks()  # checks
# Out:
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %% [markdown]
# # Start
#
# ⚡ Login with your API key, load your YOLO 🚀 model, and start training in 3 lines of code!

# %%
hub.login('6ec810a2411143c10637cec4f4936e2c225a289c73')

model = YOLO('https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR')
results = model.train()
success = model.export(format="onnx")
# Out:
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR 🚀
# Ultralytics 8.3.98 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11n.pt, data=https://app.roboflow.com/ds/9arS42UIWd?key=DWecUVOFPz, epochs=40, time=None, patience=100, batch=-1, imgsz=640, save=True, save_period=-1, cache=None, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
# Downloading https://app.roboflow.com/ds/9arS42UIWd to '9arS42UIWd'...
# 100%|██████████| 2.02G/2.02G [00:40<00:00, 53.5MB/s]
# Unzipping 9arS42UIWd to /content/datasets/9arS42UIWd...: 100%|██████████| 48478/48478 [00:34<00:00, 1406.08file/s]
# Overriding model.yaml nc=80 with nc=52
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    440812  ultralytics.nn.modules.head.Detect           [52, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,599,980 parameters, 2,599,964 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train3', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /content/datasets/9arS42UIWd/train/labels... 21203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 21203/21203 [00:45<00:00, 470.88it/s]
# train: New cache created: /content/datasets/9arS42UIWd/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# AutoBatch: Computing optimal batch size for imgsz=640 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (Tesla T4) 14.74G total, 11.94G reserved, 10.25G allocated, -7.45G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      2599980       6.495        23.503         32.68         314.3        (1, 3, 640, 640)                    list
#      2599980       12.99        23.528         29.25         79.65        (2, 3, 640, 640)                    list
#      2599980       25.98        23.545            33         68.65        (4, 3, 640, 640)                    list
#      2599980       51.96        23.897         32.77         75.36        (8, 3, 640, 640)                    list
#      2599980       103.9        25.097         48.99         93.93       (16, 3, 640, 640)                    list
# AutoBatch: WARNING ⚠️ error detected: expected non-empty vector for x,  using default batch-size 16.
# train: Scanning /content/datasets/9arS42UIWd/train/labels.cache... 21203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 21203/21203 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/9arS42UIWd/valid/labels... 2020 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2020/2020 [00:04<00:00, 483.29it/s]
# val: New cache created: /content/datasets/9arS42UIWd/valid/labels.cache
# 流式输出内容被截断，只能显示最后 5000 行内容。
#
# (14,45,.,.) =
#  0.01 *
#  -1.0017
#
# (15,45,.,.) =
#  0.001 *
#  -9.7198
#
# (16,45,.,.) =
#  0.01 *
#  -1.3550
#
# (17,45,.,.) =
#  0.001 *
#  -3.0403
#
# (18,45,.,.) =
#  0.0001 *
#  -2.1565
#
# (19,45,.,.) =
#  0.001 *
#   1.7662
#
# (20,45,.,.) =
#  0.001 *
#   2.8057
#
# (21,45,.,.) =
#  0.001 *
#   8.8120
#
# (22,45,.,.) =
#  0.01 *
#   1.6953
#
# (23,45,.,.) =
#  0.001 *
#   7.0496
#
# (24,45,.,.) =
#  0.001 *
#   4.5624
#
# (25,45,.,.) =
#  0.001 *
#   5.8556
#
# (26,45,.,.) =
#  0.001 *
#   4.0169
#
# (27,45,.,.) =
#  0.0001 *
#  -1.0902
#
# (28,45,.,.) =
#  0.001 *
#  -4.9629
#
# (29,45,.,.) =
#  0.001 *
#  -8.1558
#
# (30,45,.,.) =
#  0.001 *
#  -9.9182
#
# (31,45,.,.) =
#  0.01 *
#  -1.1070
#
# (32,45,.,.) =
#  0.01 *
#  -1.4351
#
# (33,45,.,.) =
#  0.001 *
#   8.6594
#
# (34,45,.,.) =
#  0.001 *
#   7.3128
#
# (35,45,.,.) =
#  0.001 *
#   6.0272
#
# (36,45,.,.) =
#  0.001 *
#   6.2447
#
# (37,45,.,.) =
#  0.001 *
#   8.1558
#
# (38,45,.,.) =
#  0.01 *
#   1.0742
#
# (39,45,.,.) =
#  0.001 *
#   5.5580
#
# (40,45,.,.) =
#  0.0001 *
#   7.4720
#
# (41,45,.,.) =
#  0.001 *
#  -2.1896
#
# (42,45,.,.) =
#  0.001 *
#  -7.8201
#
# (43,45,.,.) =
#  0.01 *
#  -1.0422
#
# (44,45,.,.) =
#  0.001 *
#  -8.3313
#
# (45,45,.,.) =
#  0.001 *
#  -6.3248
#
# (46,45,.,.) =
#  0.001 *
#  -6.1951
#
# (47,45,.,.) =
#  0.001 *
#  -6.5689
#
# (48,45,.,.) =
#  0.001 *
#  -5.5428
#
# (49,45,.,.) =
#  0.0001 *
#   8.6641
#
# (50,45,.,.) =
#  0.001 *
#   2.1839
#
# (51,45,.,.) =
#  0.001 *
#   2.4490
#
# (52,45,.,.) =
#  0.001 *
#   7.6637
#
# (53,45,.,.) =
#  0.01 *
#   1.4374
#
# (54,45,.,.) =
#  0.01 *
#   1.0956
#
# (55,45,.,.) =
#  0.001 *
#   4.7684
#
# (56,45,.,.) =
#  0.001 *
#   2.4624
#
# (57,45,.,.) =
#  0.001 *
#   4.5166
#
# (58,45,.,.) =
#  0.001 *
#   5.0163
#
# (59,45,.,.) =
#  0.0001 *
#  -6.9523
#
# (60,45,.,.) =
#  0.001 *
#  -7.0801
#
# (61,45,.,.) =
#  0.001 *
#  -9.6283
#
# (62,45,.,.) =
#  0.01 *
#  -1.0818
#
# (63,45,.,.) =
#  0.01 *
#  -1.1459
#
# (64,45,.,.) =
#  0.01 *
#  -1.5526
#
# (1,46,.,.) =
#  -0.2881
#
# (2,46,.,.) =
#  -0.1761
#
# (3,46,.,.) =
#  0.01 *
#   8.4778
#
# (4,46,.,.) =
#   0.1556
#
# (5,46,.,.) =
#  0.01 *
#   6.1798
#
# (6,46,.,.) =
#  0.01 *
#  -1.8768
#
# (7,46,.,.) =
#  0.001 *
#   6.5079
#
# (8,46,.,.) =
#  0.01 *
#   5.9540
#
# (9,46,.,.) =
#  0.01 *
#   7.5378
#
# (10,46,.,.) =
#  0.01 *
#   5.4352
#
# (11,46,.,.) =
#  0.01 *
#   2.2430
#
# (12,46,.,.) =
#  0.001 *
#   4.2725
#
# (13,46,.,.) =
#  0.001 *
#  -2.9125
#
# (14,46,.,.) =
#  0.001 *
#  -8.1024
#
# (15,46,.,.) =
#  0.01 *
#  -1.3000
#
# (16,46,.,.) =
#  0.01 *
#  -1.7517
#
# (17,46,.,.) =
#  0.001 *
#  -3.7003
#
# (18,46,.,.) =
#  0.0001 *
#  -2.4629
#
# (19,46,.,.) =
#  0.001 *
#   2.5806
#
# (20,46,.,.) =
#  0.001 *
#   6.3019
#
# (21,46,.,.) =
#  0.01 *
#   2.2354
#
# (22,46,.,.) =
#  0.01 *
#   3.1708
#
# (23,46,.,.) =
#  0.01 *
#   2.5482
#
# (24,46,.,.) =
#  0.01 *
#   2.0767
#
# (25,46,.,.) =
#  0.01 *
#   1.7471
#
# (26,46,.,.) =
#  0.001 *
#   6.5384
#
# (27,46,.,.) =
#  0.001 *
#  -5.5504
#
# (28,46,.,.) =
#  0.01 *
#  -1.6144
#
# (29,46,.,.) =
#  0.01 *
#  -2.2781
#
# (30,46,.,.) =
#  0.01 *
#  -2.5482
#
# (31,46,.,.) =
#  0.01 *
#  -2.6031
#
# (32,46,.,.) =
#  0.01 *
#  -3.3386
#
# (33,46,.,.) =
#  0.01 *
#   1.7212
#
# (34,46,.,.) =
#  0.01 *
#   1.6983
#
# (35,46,.,.) =
#  0.01 *
#   1.4854
#
# (36,46,.,.) =
#  0.01 *
#   1.5076
#
# (37,46,.,.) =
#  0.01 *
#   1.6846
#
# (38,46,.,.) =
#  0.01 *
#   2.2354
#
# (39,46,.,.) =
#  0.01 *
#   1.7090
#
# (40,46,.,.) =
#  0.001 *
#   9.6359
#
# (41,46,.,.) =
#  0.001 *
#   7.1411
#
# (42,46,.,.) =
#  0.001 *
#   1.8463
#
# (43,46,.,.) =
#  0.001 *
#  -7.4615
#
# (44,46,.,.) =
#  0.01 *
#  -1.7029
#
# (45,46,.,.) =
#  0.01 *
#  -2.3529
#
# (46,46,.,.) =
#  0.01 *
#  -2.7695
#
# (47,46,.,.) =
#  0.01 *
#  -3.0060
#
# (48,46,.,.) =
#  0.01 *
#  -3.3142
#
# (49,46,.,.) =
#  0.001 *
#   2.7122
#
# (50,46,.,.) =
#  0.001 *
#   6.0196
#
# (51,46,.,.) =
#  0.001 *
#   7.4539
#
# (52,46,.,.) =
#  0.01 *
#   1.5869
#
# (53,46,.,.) =
#  0.01 *
#   2.6718
#
# (54,46,.,.) =
#  0.01 *
#   2.5696
#
# (55,46,.,.) =
#  0.01 *
#   1.9501
#
# (56,46,.,.) =
#  0.01 *
#   1.3573
#
# (57,46,.,.) =
#  0.01 *
#   1.0109
#
# (58,46,.,.) =
#  0.001 *
#   5.5885
#
# (59,46,.,.) =
#  0.001 *
#  -4.8256
#
# (60,46,.,.) =
#  0.01 *
#  -1.7334
#
# (61,46,.,.) =
#  0.01 *
#  -2.3758
#
# (62,46,.,.) =
#  0.01 *
#  -2.6016
#
# (63,46,.,.) =
#  0.01 *
#  -2.6169
#
# (64,46,.,.) =
#  0.01 *
#  -3.5156
#
# (1,47,.,.) =
#  0.01 *
#   1.0788
#
# (2,47,.,.) =
#  0.01 *
#   1.1436
#
# (3,47,.,.) =
#  0.001 *
#   9.0256
#
# (4,47,.,.) =
#  0.01 *
#   1.0185
#
# (5,47,.,.) =
#  0.001 *
#  -3.8815
#
# (6,47,.,.) =
#  0.001 *
#  -7.4577
#
# (7,47,.,.) =
#  0.01 *
#  -1.0612
#
# (8,47,.,.) =
#  0.001 *
#  -7.2021
#
# (9,47,.,.) =
#  0.001 *
#  -2.1496
#
# (10,47,.,.) =
#  0.001 *
#  -2.1133
#
# (11,47,.,.) =
#  0.001 *
#  -1.8454
#
# (12,47,.,.) =
#  0.001 *
#  -1.5831
#
# (13,47,.,.) =
#  0.001 *
#  -1.6565
#
# (14,47,.,.) =
#  0.001 *
#  -2.0504
#
# (15,47,.,.) =
#  0.001 *
#  -2.4490
#
# (16,47,.,.) =
#  0.001 *
#   1.5106
#
# (17,47,.,.) =
#   0.1812
#
# (18,47,.,.) =
#  -0.1522
#
# (19,47,.,.) =
#  0.01 *
#  -2.0401
#
# (20,47,.,.) =
#  0.01 *
#   1.9958
#
# (21,47,.,.) =
#  0.0001 *
#   4.2653
#
# (22,47,.,.) =
#  0.001 *
#  -8.2092
#
# (23,47,.,.) =
#  0.01 *
#   1.0429
#
# (24,47,.,.) =
#  0.001 *
#   6.1493
#
# (25,47,.,.) =
#  0.001 *
#  -6.8550
#
# (26,47,.,.) =
#  0.001 *
#  -7.9346
#
# (27,47,.,.) =
#  0.001 *
#  -5.9319
#
# (28,47,.,.) =
#  0.001 *
#  -4.7150
#
# (29,47,.,.) =
#  0.001 *
#  -3.9444
#
# (30,47,.,.) =
#  0.001 *
#  -3.4504
#
# (31,47,.,.) =
#  0.001 *
#  -3.2616
#
# (32,47,.,.) =
#  0.001 *
#  -1.1673
#
# (33,47,.,.) =
#  0.001 *
#   7.5493
#
# (34,47,.,.) =
#  0.001 *
#   4.6463
#
# (35,47,.,.) =
#  0.001 *
#   3.2101
#
# (36,47,.,.) =
#  0.0001 *
#  -4.6372
#
# (37,47,.,.) =
#  0.001 *
#  -8.6594
#
# (38,47,.,.) =
#  0.001 *
#  -3.5381
#
# (39,47,.,.) =
#  0.001 *
#   3.0460
#
# (40,47,.,.) =
#  0.001 *
#   1.3170
#
# (41,47,.,.) =
#  0.0001 *
#   9.0694
#
# (42,47,.,.) =
#  0.0001 *
#   1.4329
#
# (43,47,.,.) =
#  0.001 *
#  -1.3933
#
# (44,47,.,.) =
#  0.001 *
#  -2.0618
#
# (45,47,.,.) =
#  0.001 *
#  -2.1038
#
# (46,47,.,.) =
#  0.001 *
#  -2.1896
#
# (47,47,.,.) =
#  0.001 *
#  -2.2793
#
# (48,47,.,.) =
#  0.001 *
#   1.8730
#
# (49,47,.,.) =
#  0.001 *
#   8.3694
#
# (50,47,.,.) =
#  0.001 *
#   8.5754
#
# (51,47,.,.) =
#  0.001 *
#   7.4081
#
# (52,47,.,.) =
#  0.001 *
#   2.6970
#
# (53,47,.,.) =
#  0.0001 *
#   5.2214
#
# (54,47,.,.) =
#  0.001 *
#  -5.5542
#
# (55,47,.,.) =
#  0.001 *
#  -4.5128
#
# (56,47,.,.) =
#  0.001 *
#  -5.9090
#
# (57,47,.,.) =
#  0.001 *
#  -3.5686
#
# (58,47,.,.) =
#  0.001 *
#  -4.2419
#
# (59,47,.,.) =
#  0.001 *
#  -3.0174
#
# (60,47,.,.) =
#  0.0001 *
#  -9.0170
#
# (61,47,.,.) =
#  0.0001 *
#  -1.5366
#
# (62,47,.,.) =
#  0.0001 *
#  -4.7374
#
# (63,47,.,.) =
#  0.0001 *
#  -8.8978
#
# (64,47,.,.) =
#  0.001 *
#   1.6747
#
# (1,48,.,.) =
#  0.01 *
#   1.0933
#
# (2,48,.,.) =
#  0.01 *
#   1.0712
#
# (3,48,.,.) =
#  0.001 *
#   9.0714
#
# (4,48,.,.) =
#  0.001 *
#   6.9656
#
# (5,48,.,.) =
#  0.001 *
#   6.2447
#
# (6,48,.,.) =
#  0.001 *
#   2.2221
#
# (7,48,.,.) =
#  0.001 *
#   4.6921
#
# (8,48,.,.) =
#  0.001 *
#   4.6120
#
# (9,48,.,.) =
#  0.001 *
#  -2.1534
#
# (10,48,.,.) =
#  0.001 *
#  -4.0283
#
# (11,48,.,.) =
#  0.001 *
#  -5.3291
#
# (12,48,.,.) =
#  0.001 *
#  -7.0457
#
# (13,48,.,.) =
#  0.001 *
#  -8.3542
#
# (14,48,.,.) =
#  0.001 *
#  -8.8348
#
# (15,48,.,.) =
#  0.001 *
#  -8.8654
#
# (16,48,.,.) =
#  0.01 *
#  -1.0803
#
# (17,48,.,.) =
#  0.01 *
#  -6.6406
#
# (18,48,.,.) =
#  0.01 *
#   4.5502
#
# (19,48,.,.) =
#  0.01 *
#   4.1779
#
# (20,48,.,.) =
#  -0.1010
#
# (21,48,.,.) =
#  -0.1180
#
# (22,48,.,.) =
#  0.01 *
#   1.3168
#
# (23,48,.,.) =
#   0.1505
#
# (24,48,.,.) =
#   0.1389
#
# (25,48,.,.) =
#  0.01 *
#   5.9631
#
# (26,48,.,.) =
#  0.001 *
#  -2.8934
#
# (27,48,.,.) =
#  0.01 *
#  -3.1219
#
# (28,48,.,.) =
#  0.01 *
#  -3.4821
#
# (29,48,.,.) =
#  0.01 *
#  -2.8900
#
# (30,48,.,.) =
#  0.01 *
#  -2.2049
#
# (31,48,.,.) =
#  0.01 *
#  -1.7105
#
# (32,48,.,.) =
#  0.01 *
#  -2.7069
#
# (33,48,.,.) =
#  0.001 *
#   4.7531
#
# (34,48,.,.) =
#  0.001 *
#   5.0163
#
# (35,48,.,.) =
#  0.001 *
#   7.6180
#
# (36,48,.,.) =
#  0.001 *
#   6.2790
#
# (37,48,.,.) =
#  0.001 *
#   8.4305
#
# (38,48,.,.) =
#  0.001 *
#   4.9362
#
# (39,48,.,.) =
#  0.0001 *
#   5.0735
#
# (40,48,.,.) =
#  0.001 *
#  -1.2350
#
# (41,48,.,.) =
#  0.001 *
#  -3.3054
#
# (42,48,.,.) =
#  0.001 *
#  -4.7150
#
# (43,48,.,.) =
#  0.001 *
#  -4.0970
#
# (44,48,.,.) =
#  0.001 *
#  -3.9043
#
# (45,48,.,.) =
#  0.001 *
#  -4.1847
#
# (46,48,.,.) =
#  0.001 *
#  -5.0201
#
# (47,48,.,.) =
#  0.001 *
#  -5.8823
#
# (48,48,.,.) =
#  0.001 *
#  -5.2032
#
# (49,48,.,.) =
#  0.001 *
#   4.4708
#
# (50,48,.,.) =
#  0.001 *
#   5.6877
#
# (51,48,.,.) =
#  0.001 *
#   4.8561
#
# (52,48,.,.) =
#  0.001 *
#   5.1155
#
# (53,48,.,.) =
#  0.001 *
#   7.0686
#
# (54,48,.,.) =
#  0.001 *
#   4.7188
#
# (55,48,.,.) =
#  0.001 *
#  -1.9474
#
# (56,48,.,.) =
#  0.001 *
#  -2.4815
#
# (57,48,.,.) =
#  0.001 *
#  -5.0697
#
# (58,48,.,.) =
#  0.01 *
#  -1.3329
#
# (59,48,.,.) =
#  0.01 *
#  -1.5656
#
# (60,48,.,.) =
#  0.001 *
#  -5.8899
#
# (61,48,.,.) =
#  0.001 *
#   1.4973
#
# (62,48,.,.) =
#  0.001 *
#   3.5515
#
# (63,48,.,.) =
#  0.001 *
#   2.8515
#
# (64,48,.,.) =
#  0.001 *
#   4.6158
#
# (1,49,.,.) =
#  0.001 *
#  -7.3814
#
# (2,49,.,.) =
#  0.001 *
#  -6.4774
#
# (3,49,.,.) =
#  0.001 *
#  -4.4556
#
# (4,49,.,.) =
#  0.001 *
#   1.8845
#
# (5,49,.,.) =
#  0.001 *
#   7.4692
#
# (6,49,.,.) =
#  0.01 *
#   1.3168
#
# (7,49,.,.) =
#  0.01 *
#   1.0262
#
# (8,49,.,.) =
#  0.01 *
#   1.5205
#
# (9,49,.,.) =
#  0.01 *
#   1.2817
#
# (10,49,.,.) =
#  0.001 *
#   7.2441
#
# (11,49,.,.) =
#  0.001 *
#   1.3170
#
# (12,49,.,.) =
#  0.001 *
#  -3.9940
#
# (13,49,.,.) =
#  0.001 *
#  -7.8812
#
# (14,49,.,.) =
#  0.01 *
#  -1.0239
#
# (15,49,.,.) =
#  0.01 *
#  -1.1688
#
# (16,49,.,.) =
#  0.01 *
#  -1.7334
#
# (17,49,.,.) =
#  -0.1238
#
# (18,49,.,.) =
#   0.1470
#
# (19,49,.,.) =
#   0.1531
#
# (20,49,.,.) =
#   0.1311
#
# (21,49,.,.) =
#  0.01 *
#  -3.5461
#
# (22,49,.,.) =
#  0.01 *
#  -5.5237
#
# (23,49,.,.) =
#  0.01 *
#  -4.6875
#
# (24,49,.,.) =
#  0.01 *
#  -3.1204
#
# (25,49,.,.) =
#  0.01 *
#  -2.6703
#
# (26,49,.,.) =
#  0.01 *
#  -2.2293
#
# (27,49,.,.) =
#  0.01 *
#  -1.9272
#
# (28,49,.,.) =
#  0.01 *
#  -1.6434
#
# (29,49,.,.) =
#  0.01 *
#  -1.4053
#
# (30,49,.,.) =
#  0.01 *
#  -1.2367
#
# (31,49,.,.) =
#  0.01 *
#  -1.1520
#
# (32,49,.,.) =
#  0.01 *
#  -1.5839
#
# (33,49,.,.) =
#  0.001 *
#   4.3488
#
# (34,49,.,.) =
#  0.001 *
#   4.3793
#
# (35,49,.,.) =
#  0.001 *
#   4.6387
#
# (36,49,.,.) =
#  0.001 *
#   3.0270
#
# (37,49,.,.) =
#  0.0001 *
#   9.4891
#
# (38,49,.,.) =
#  0.001 *
#   9.2239
#
# (39,49,.,.) =
#  0.001 *
#   5.4550
#
# (40,49,.,.) =
#  0.0001 *
#   9.0742
#
# (41,49,.,.) =
#  0.001 *
#  -4.2839
#
# (42,49,.,.) =
#  0.001 *
#  -2.7809
#
# (43,49,.,.) =
#  0.0001 *
#  -4.0650
#
# (44,49,.,.) =
#  1e-06 *
#   7.8678
#
# (45,49,.,.) =
#  0.001 *
#  -2.2812
#
# (46,49,.,.) =
#  0.001 *
#  -5.1270
#
# (47,49,.,.) =
#  0.001 *
#  -7.4615
#
# (48,49,.,.) =
#  0.01 *
#  -1.0559
#
# (49,49,.,.) =
#  0.01 *
#   1.3550
#
# (50,49,.,.) =
#  0.001 *
#   9.4528
#
# (51,49,.,.) =
#  0.001 *
#   9.1782
#
# (52,49,.,.) =
#  0.001 *
#   4.9896
#
# (53,49,.,.) =
#  0.0001 *
#  -2.0576
#
# (54,49,.,.) =
#  0.001 *
#   3.4580
#
# (55,49,.,.) =
#  0.01 *
#   1.0101
#
# (56,49,.,.) =
#  0.001 *
#   7.7744
#
# (57,49,.,.) =
#  0.001 *
#   1.6432
#
# (58,49,.,.) =
#  0.0001 *
#  -9.1696
#
# (59,49,.,.) =
#  0.001 *
#  -4.4670
#
# (60,49,.,.) =
#  0.001 *
#  -9.0561
#
# (61,49,.,.) =
#  0.01 *
#  -1.0628
#
# (62,49,.,.) =
#  0.01 *
#  -1.0841
#
# (63,49,.,.) =
#  0.01 *
#  -1.0559
#
# (64,49,.,.) =
#  0.01 *
#  -1.3435
#
# (1,50,.,.) =
#  0.01 *
#   2.7832
#
# (2,50,.,.) =
#  0.01 *
#   2.6581
#
# (3,50,.,.) =
#  0.01 *
#   2.4368
#
# (4,50,.,.) =
#  0.01 *
#   1.8341
#
# (5,50,.,.) =
#  0.001 *
#   9.1171
#
# (6,50,.,.) =
#  0.001 *
#  -3.7079
#
# (7,50,.,.) =
#  0.01 *
#  -1.2398
#
# (8,50,.,.) =
#  0.01 *
#  -1.5015
#
# (9,50,.,.) =
#  0.01 *
#  -1.4740
#
# (10,50,.,.) =
#  0.01 *
#  -1.6296
#
# (11,50,.,.) =
#  0.01 *
#  -1.5884
#
# (12,50,.,.) =
#  0.01 *
#  -1.2787
#
# (13,50,.,.) =
#  0.001 *
#  -9.1248
#
# (14,50,.,.) =
#  0.001 *
#  -6.5193
#
# (15,50,.,.) =
#  0.001 *
#  -4.6692
#
# (16,50,.,.) =
#  0.001 *
#   4.8752
#
# (17,50,.,.) =
#   0.2201
#
# (18,50,.,.) =
#   0.2487
#
# (19,50,.,.) =
#   0.1370
#
# (20,50,.,.) =
#  -0.1076
#
# (21,50,.,.) =
#  -0.1605
#
# (22,50,.,.) =
#  -0.1106
#
# (23,50,.,.) =
#  0.01 *
#  -7.0251
#
# (24,50,.,.) =
#  0.01 *
#  -3.9948
#
# (25,50,.,.) =
#  0.01 *
#  -2.5635
#
# (26,50,.,.) =
#  0.01 *
#  -1.9897
#
# (27,50,.,.) =
#  0.01 *
#  -1.6388
#
# (28,50,.,.) =
#  0.01 *
#  -1.3313
#
# (29,50,.,.) =
#  0.01 *
#  -1.1032
#
# (30,50,.,.) =
#  0.001 *
#  -9.7351
#
# (31,50,.,.) =
#  0.001 *
#  -9.0561
#
# (32,50,.,.) =
#  0.01 *
#  -1.2756
#
# (33,50,.,.) =
#  0.01 *
#   2.3178
#
# (34,50,.,.) =
#  0.01 *
#   2.3193
#
# (35,50,.,.) =
#  0.01 *
#   2.1255
#
# (36,50,.,.) =
#  0.01 *
#   1.7776
#
# (37,50,.,.) =
#  0.01 *
#   1.1726
#
# (38,50,.,.) =
#  1e-05 *
#  -7.3195
#
# (39,50,.,.) =
#  0.001 *
#  -5.5542
#
# (40,50,.,.) =
#  0.001 *
#  -8.7509
#
# (41,50,.,.) =
#  0.01 *
#  -1.1307
#
# (42,50,.,.) =
#  0.01 *
#  -1.2703
#
# (43,50,.,.) =
#  0.01 *
#  -1.4671
#
# (44,50,.,.) =
#  0.01 *
#  -1.4214
#
# (45,50,.,.) =
#  0.01 *
#  -1.2405
#
# (46,50,.,.) =
#  0.001 *
#  -9.8572
#
# (47,50,.,.) =
#  0.001 *
#  -7.9117
#
# (48,50,.,.) =
#  0.0001 *
#   3.4094
#
# (49,50,.,.) =
#  0.01 *
#   3.1235
#
# (50,50,.,.) =
#  0.01 *
#   3.0212
#
# (51,50,.,.) =
#  0.01 *
#   2.9373
#
# (52,50,.,.) =
#  0.01 *
#   2.4292
#
# (53,50,.,.) =
#  0.01 *
#   2.0401
#
# (54,50,.,.) =
#  0.001 *
#   8.6441
#
# (55,50,.,.) =
#  0.01 *
#  -1.1322
#
# (56,50,.,.) =
#  0.01 *
#  -2.2446
#
# (57,50,.,.) =
#  0.01 *
#  -2.1332
#
# (58,50,.,.) =
#  0.01 *
#  -1.9669
#
# (59,50,.,.) =
#  0.01 *
#  -1.7639
#
# (60,50,.,.) =
#  0.01 *
#  -1.4313
#
# (61,50,.,.) =
#  0.01 *
#  -1.1169
#
# (62,50,.,.) =
#  0.001 *
#  -8.7509
#
# (63,50,.,.) =
#  0.001 *
#  -7.1831
#
# (64,50,.,.) =
#  0.01 *
#  -1.0002
#
# (1,51,.,.) =
#   0.2113
#
# (2,51,.,.) =
#   0.2107
#
# (3,51,.,.) =
#  -0.1444
#
# (4,51,.,.) =
#  0.01 *
#  -8.1360
#
# (5,51,.,.) =
#  0.01 *
#  -3.3600
#
# (6,51,.,.) =
#  0.01 *
#  -2.5284
#
# (7,51,.,.) =
#  0.01 *
#  -2.6718
#
# (8,51,.,.) =
#  0.01 *
#  -2.7328
#
# (9,51,.,.) =
#  0.01 *
#  -2.2125
#
# (10,51,.,.) =
#  0.01 *
#  -1.4717
#
# (11,51,.,.) =
#  0.01 *
#  -1.1162
#
# (12,51,.,.) =
#  0.001 *
#  -8.7738
#
# (13,51,.,.) =
#  0.001 *
#  -7.2632
#
# (14,51,.,.) =
#  0.001 *
#  -6.5384
#
# (15,51,.,.) =
#  0.001 *
#  -6.1607
#
# (16,51,.,.) =
#  0.001 *
#  -7.6180
#
# (17,51,.,.) =
#  0.001 *
#   6.9237
#
# (18,51,.,.) =
#  0.001 *
#   4.7684
#
# (19,51,.,.) =
#  0.001 *
#   6.5842
#
# (20,51,.,.) =
#  0.001 *
#   5.0011
#
# (21,51,.,.) =
#  0.001 *
#   8.0795
#
# (22,51,.,.) =
#  0.01 *
#   1.5129
#
# (23,51,.,.) =
#  1e-05 *
#  -1.9014
#
# (24,51,.,.) =
#  0.001 *
#  -7.0419
#
# (25,51,.,.) =
#  0.001 *
#  -4.1542
#
# (26,51,.,.) =
#  0.001 *
#  -4.8141
#
# (27,51,.,.) =
#  0.001 *
#  -6.8817
#
# (28,51,.,.) =
#  0.001 *
#  -8.1863
#
# (29,51,.,.) =
#  0.001 *
#  -7.9498
#
# (30,51,.,.) =
#  0.001 *
#  -7.0648
#
# (31,51,.,.) =
#  0.001 *
#  -5.9204
#
# (32,51,.,.) =
#  0.001 *
#   5.6458
#
# (33,51,.,.) =
#  0.01 *
#   1.2482
#
# (34,51,.,.) =
#  0.01 *
#   1.3779
#
# (35,51,.,.) =
#  0.01 *
#   1.3847
#
# (36,51,.,.) =
#  0.01 *
#   1.5305
#
# (37,51,.,.) =
#  0.01 *
#   1.2238
#
# (38,51,.,.) =
#  0.01 *
#   1.7365
#
# (39,51,.,.) =
#  0.0001 *
#  -4.4823
#
# (40,51,.,.) =
#  0.01 *
#  -1.0498
#
# (41,51,.,.) =
#  0.01 *
#  -1.2367
#
# (42,51,.,.) =
#  0.01 *
#  -1.1688
#
# (43,51,.,.) =
#  0.01 *
#  -1.0597
#
# (44,51,.,.) =
#  0.001 *
#  -9.3536
#
# (45,51,.,.) =
#  0.001 *
#  -8.0338
#
# (46,51,.,.) =
#  0.001 *
#  -7.0343
#
# (47,51,.,.) =
#  0.001 *
#  -6.1951
#
# (48,51,.,.) =
#  0.001 *
#  -8.6441
#
# (49,51,.,.) =
#  0.001 *
#   5.1804
#
# (50,51,.,.) =
#  0.001 *
#   4.0550
#
# (51,51,.,.) =
#  0.001 *
#   4.2915
#
# (52,51,.,.) =
#  0.001 *
#   4.7760
#
# (53,51,.,.) =
#  0.01 *
#   1.6556
#
# (54,51,.,.) =
#  0.01 *
#   1.3405
#
# (55,51,.,.) =
#  1e-05 *
#  -8.8751
#
# (56,51,.,.) =
#  0.001 *
#  -3.2520
#
# (57,51,.,.) =
#  0.001 *
#   1.1406
#
# (58,51,.,.) =
#  0.0001 *
#  -2.4915
#
# (59,51,.,.) =
#  0.001 *
#  -8.1329
#
# (60,51,.,.) =
#  0.01 *
#  -1.2146
#
# (61,51,.,.) =
#  0.01 *
#  -1.0590
#
# (62,51,.,.) =
#  0.001 *
#  -7.9193
#
# (63,51,.,.) =
#  0.001 *
#  -5.7297
#
# (64,51,.,.) =
#  0.001 *
#  -1.1168
#
# (1,52,.,.) =
#  0.01 *
#   2.7344
#
# (2,52,.,.) =
#  0.01 *
#   2.7435
#
# (3,52,.,.) =
#  0.01 *
#   2.5436
#
# (4,52,.,.) =
#  0.01 *
#   1.7120
#
# (5,52,.,.) =
#  0.01 *
#   2.0248
#
# (6,52,.,.) =
#  0.01 *
#   1.5900
#
# (7,52,.,.) =
#  0.001 *
#   4.8218
#
# (8,52,.,.) =
#  0.001 *
#  -4.5242
#
# (9,52,.,.) =
#  0.01 *
#  -1.0689
#
# (10,52,.,.) =
#  0.01 *
#  -1.0948
#
# (11,52,.,.) =
#  0.01 *
#  -1.0521
#
# (12,52,.,.) =
#  0.01 *
#  -1.2718
#
# (13,52,.,.) =
#  0.01 *
#  -1.6449
#
# (14,52,.,.) =
#  0.01 *
#  -1.9440
#
# (15,52,.,.) =
#  0.01 *
#  -2.1500
#
# (16,52,.,.) =
#  0.01 *
#  -3.1555
#
# (17,52,.,.) =
#  0.01 *
#   1.7944
#
# (18,52,.,.) =
#  0.01 *
#   4.9408
#
# (19,52,.,.) =
#   0.1119
#
# (20,52,.,.) =
#   0.2321
#
# (21,52,.,.) =
#   0.1825
#
# (22,52,.,.) =
#  0.01 *
#  -7.3730
#
# (23,52,.,.) =
#  -0.1078
#
# (24,52,.,.) =
#  0.01 *
#  -8.6975
#
# (25,52,.,.) =
#  0.01 *
#  -6.6284
#
# (26,52,.,.) =
#  0.01 *
#  -5.3375
#
# (27,52,.,.) =
#  0.01 *
#  -4.5959
#
# (28,52,.,.) =
#  0.01 *
#  -3.9276
#
# (29,52,.,.) =
#  0.01 *
#  -3.2898
#
# (30,52,.,.) =
#  0.01 *
#  -2.8519
#
# (31,52,.,.) =
#  0.01 *
#  -2.5818
#
# (32,52,.,.) =
#  0.01 *
#  -3.3020
#
# (33,52,.,.) =
#  0.01 *
#   2.3148
#
# (34,52,.,.) =
#  0.01 *
#   2.3529
#
# (35,52,.,.) =
#  0.01 *
#   2.2476
#
# (36,52,.,.) =
#  0.01 *
#   2.4170
#
# (37,52,.,.) =
#  0.01 *
#   2.5803
#
# (38,52,.,.) =
#  0.01 *
#   1.3351
#
# (39,52,.,.) =
#  0.001 *
#   7.6942
#
# (40,52,.,.) =
#  0.001 *
#   3.3150
#
# (41,52,.,.) =
#  0.001 *
#  -3.7174
#
# (42,52,.,.) =
#  0.01 *
#  -1.0323
#
# (43,52,.,.) =
#  0.01 *
#  -1.5587
#
# (44,52,.,.) =
#  0.01 *
#  -1.8356
#
# (45,52,.,.) =
#  0.01 *
#  -1.9836
#
# (46,52,.,.) =
#  0.01 *
#  -2.0874
#
# (47,52,.,.) =
#  0.01 *
#  -2.2186
#
# (48,52,.,.) =
#  0.01 *
#  -3.2379
#
# (49,52,.,.) =
#  0.01 *
#   2.5696
#
# (50,52,.,.) =
#  0.01 *
#   2.7878
#
# (51,52,.,.) =
#  0.01 *
#   2.7664
#
# (52,52,.,.) =
#  0.01 *
#   3.0365
#
# (53,52,.,.) =
#  0.01 *
#   3.3142
#
# (54,52,.,.) =
#  0.01 *
#   2.8915
#
# (55,52,.,.) =
#  0.001 *
#   8.5297
#
# (56,52,.,.) =
#  0.01 *
#  -1.0651
#
# (57,52,.,.) =
#  0.01 *
#  -1.7822
#
# (58,52,.,.) =
#  0.01 *
#  -2.0142
#
# (59,52,.,.) =
#  0.01 *
#  -2.0752
#
# (60,52,.,.) =
#  0.01 *
#  -2.1164
#
# (61,52,.,.) =
#  0.01 *
#  -2.2186
#
# (62,52,.,.) =
#  0.01 *
#  -2.2400
#
# (63,52,.,.) =
#  0.01 *
#  -2.2064
#
# (64,52,.,.) =
#  0.01 *
#  -2.4918
#
# (1,53,.,.) =
#  0.01 *
#   1.4992
#
# (2,53,.,.) =
#  0.01 *
#   1.3779
#
# (3,53,.,.) =
#  0.01 *
#   1.2047
#
# (4,53,.,.) =
#  0.001 *
#   6.3705
#
# (5,53,.,.) =
#  0.001 *
#  -1.2894
#
# (6,53,.,.) =
#  0.001 *
#  -6.8436
#
# (7,53,.,.) =
#  0.001 *
#  -4.7798
#
# (8,53,.,.) =
#  0.0001 *
#  -4.9353
#
# (9,53,.,.) =
#  0.001 *
#  -1.0204
#
# (10,53,.,.) =
#  0.001 *
#  -1.7118
#
# (11,53,.,.) =
#  0.001 *
#  -1.8511
#
# (12,53,.,.) =
#  0.001 *
#  -2.9888
#
# (13,53,.,.) =
#  0.001 *
#  -5.2490
#
# (14,53,.,.) =
#  0.001 *
#  -6.6757
#
# (15,53,.,.) =
#  0.001 *
#  -7.1411
#
# (16,53,.,.) =
#  0.001 *
#  -7.1564
#
# (17,53,.,.) =
#  0.001 *
#  -4.9553
#
# (18,53,.,.) =
#  0.001 *
#  -1.8635
#
# (19,53,.,.) =
#  0.0001 *
#  -5.4550
#
# (20,53,.,.) =
#  0.0001 *
#  -3.4261
#
# (21,53,.,.) =
#  0.001 *
#  -2.6531
#
# (22,53,.,.) =
#  0.001 *
#  -5.1308
#
# (23,53,.,.) =
#  0.001 *
#  -4.3182
#
# (24,53,.,.) =
#  0.001 *
#  -4.5738
#
# (25,53,.,.) =
#  0.001 *
#  -9.0332
#
# (26,53,.,.) =
#  0.01 *
#  -1.2825
#
# (27,53,.,.) =
#  0.01 *
#  -1.1749
#
# (28,53,.,.) =
#  0.001 *
#  -4.1924
#
# (29,53,.,.) =
#  0.001 *
#   4.5662
#
# (30,53,.,.) =
#  0.001 *
#   9.8953
#
# (31,53,.,.) =
#  0.01 *
#   1.3519
#
# (32,53,.,.) =
#  0.01 *
#   3.4210
#
# (33,53,.,.) =
#  0.001 *
#   8.6746
#
# (34,53,.,.) =
#  0.001 *
#   8.2245
#
# (35,53,.,.) =
#  0.001 *
#   6.5231
#
# (36,53,.,.) =
#  0.001 *
#   1.1892
#
# (37,53,.,.) =
#  0.001 *
#  -2.4548
#
# (38,53,.,.) =
#  0.001 *
#  -5.4474
#
# (39,53,.,.) =
#  0.001 *
#  -1.7452
#
# (40,53,.,.) =
#  0.001 *
#   2.5654
#
# (41,53,.,.) =
#  0.001 *
#   1.8759
#
# (42,53,.,.) =
#  0.0001 *
#   2.8992
#
# (43,53,.,.) =
#  0.0001 *
#  -4.9829
#
# (44,53,.,.) =
#  0.001 *
#  -1.7767
#
# (45,53,.,.) =
#  0.001 *
#  -3.3684
#
# (46,53,.,.) =
#  0.001 *
#  -4.6921
#
# (47,53,.,.) =
#  0.001 *
#  -5.4207
#
# (48,53,.,.) =
#  0.001 *
#  -3.9558
#
# (49,53,.,.) =
#  0.01 *
#  -3.1342
#
# (50,53,.,.) =
#  0.01 *
#  -3.0518
#
# (51,53,.,.) =
#  0.01 *
#  -1.9943
#
# (52,53,.,.) =
#  0.01 *
#   2.1210
#
# (53,53,.,.) =
#  0.01 *
#  -3.5767
#
# (54,53,.,.) =
#  -0.1082
#
# (55,53,.,.) =
#  -0.1266
#
# (56,53,.,.) =
#  -0.1219
#
# (57,53,.,.) =
#  0.01 *
#  -8.3679
#
# (58,53,.,.) =
#  0.01 *
#   1.6266
#
# (59,53,.,.) =
#  0.01 *
#   8.6670
#
# (60,53,.,.) =
#  0.01 *
#   9.8694
#
# (61,53,.,.) =
#  0.01 *
#   8.5815
#
# (62,53,.,.) =
#  0.01 *
#   7.3792
#
# (63,53,.,.) =
#  0.01 *
#   6.5186
#
# (64,53,.,.) =
#   0.1104
#
# (1,54,.,.) =
#  0.01 *
#   2.2156
#
# (2,54,.,.) =
#  0.01 *
#   2.4109
#
# (3,54,.,.) =
#  0.01 *
#   1.9226
#
# (4,54,.,.) =
#  0.001 *
#   6.0272
#
# (5,54,.,.) =
#  0.001 *
#  -5.0011
#
# (6,54,.,.) =
#  0.0001 *
#   4.8232
#
# (7,54,.,.) =
#  0.01 *
#   1.3947
#
# (8,54,.,.) =
#  0.01 *
#   1.5572
#
# (9,54,.,.) =
#  0.001 *
#   7.8735
#
# (10,54,.,.) =
#  0.001 *
#  -1.4257
#
# (11,54,.,.) =
#  0.001 *
#  -9.4376
#
# (12,54,.,.) =
#  0.01 *
#  -1.4969
#
# (13,54,.,.) =
#  0.01 *
#  -1.8570
#
# (14,54,.,.) =
#  0.01 *
#  -2.0065
#
# (15,54,.,.) =
#  0.01 *
#  -2.0615
#
# (16,54,.,.) =
#  0.01 *
#  -1.9577
#
# (17,54,.,.) =
#  0.001 *
#   9.9411
#
# (18,54,.,.) =
#  0.01 *
#   1.1192
#
# (19,54,.,.) =
#  0.01 *
#   1.5053
#
# (20,54,.,.) =
#  0.01 *
#   2.0264
#
# (21,54,.,.) =
#  0.01 *
#   1.4565
#
# (22,54,.,.) =
#  0.001 *
#   7.7095
#
# (23,54,.,.) =
#  0.001 *
#   9.6588
#
# (24,54,.,.) =
#  0.001 *
#   4.9553
#
# (25,54,.,.) =
#  0.001 *
#  -2.3632
#
# (26,54,.,.) =
#  0.001 *
#  -3.8376
#
# (27,54,.,.) =
#  0.001 *
#  -5.9319
#
# (28,54,.,.) =
#  0.001 *
#  -9.8038
#
# (29,54,.,.) =
#  0.01 *
#  -1.3374
#
# (30,54,.,.) =
#  0.01 *
#  -1.6159
#
# (31,54,.,.) =
#  0.01 *
#  -1.7868
#
# (32,54,.,.) =
#  0.01 *
#  -2.4017
#
# (33,54,.,.) =
#  -0.1835
#
# (34,54,.,.) =
#   0.1085
#
# (35,54,.,.) =
#  0.01 *
#   5.8350
#
# (36,54,.,.) =
#   0.1039
#
# (37,54,.,.) =
#  0.01 *
#   2.2827
#
# (38,54,.,.) =
#  0.01 *
#   4.0649
#
# (39,54,.,.) =
#  0.001 *
#  -1.0586
#
# (40,54,.,.) =
#  0.001 *
#  -4.8256
#
# (41,54,.,.) =
#  0.001 *
#  -2.4757
#
# (42,54,.,.) =
#  0.01 *
#  -1.6449
#
# (43,54,.,.) =
#  0.01 *
#  -2.1820
#
# (44,54,.,.) =
#  0.01 *
#  -2.2888
#
# (45,54,.,.) =
#  0.01 *
#  -2.1729
#
# (46,54,.,.) =
#  0.01 *
#  -2.0798
#
# (47,54,.,.) =
#  0.01 *
#  -2.0248
#
# (48,54,.,.) =
#  0.01 *
#  -1.8494
#
# (49,54,.,.) =
#  0.001 *
#   9.5062
#
# (50,54,.,.) =
#  0.001 *
#   8.5983
#
# (51,54,.,.) =
#  0.001 *
#   9.6054
#
# (52,54,.,.) =
#  0.01 *
#   1.2901
#
# (53,54,.,.) =
#  0.01 *
#   1.8723
#
# (54,54,.,.) =
#  0.01 *
#   1.5190
#
# (55,54,.,.) =
#  0.001 *
#   4.9706
#
# (56,54,.,.) =
#  0.0001 *
#   6.6996
#
# (57,54,.,.) =
#  0.001 *
#   2.2449
#
# (58,54,.,.) =
#  0.001 *
#  -1.5869
#
# (59,54,.,.) =
#  0.001 *
#  -4.4518
#
# (60,54,.,.) =
#  0.001 *
#  -7.9041
#
# (61,54,.,.) =
#  0.01 *
#  -1.2077
#
# (62,54,.,.) =
#  0.01 *
#  -1.5549
#
# (63,54,.,.) =
#  0.01 *
#  -1.7426
#
# (64,54,.,.) =
#  0.01 *
#  -2.3239
#
# (1,55,.,.) =
#  0.001 *
#   8.3160
#
# (2,55,.,.) =
#  0.001 *
#   8.1482
#
# (3,55,.,.) =
#  0.001 *
#   4.0245
#
# (4,55,.,.) =
#  0.001 *
#   7.4043
#
# (5,55,.,.) =
#  0.01 *
#   1.4557
#
# (6,55,.,.) =
#  0.01 *
#   1.7288
#
# (7,55,.,.) =
#  0.001 *
#   8.6899
#
# (8,55,.,.) =
#  0.0001 *
#   7.3624
#
# (9,55,.,.) =
#  0.001 *
#  -1.6727
#
# (10,55,.,.) =
#  0.001 *
#  -5.2643
#
# (11,55,.,.) =
#  0.001 *
#  -7.4196
#
# (12,55,.,.) =
#  0.001 *
#  -7.3280
#
# (13,55,.,.) =
#  0.001 *
#  -8.8120
#
# (14,55,.,.) =
#  0.01 *
#  -1.1261
#
# (15,55,.,.) =
#  0.01 *
#  -1.3275
#
# (16,55,.,.) =
#  0.01 *
#  -1.4221
#
# (17,55,.,.) =
#  0.001 *
#   6.6681
#
# (18,55,.,.) =
#  0.001 *
#   6.7482
#
# (19,55,.,.) =
#  0.001 *
#   7.6561
#
# (20,55,.,.) =
#  0.001 *
#   9.5367
#
# (21,55,.,.) =
#  0.01 *
#   1.4778
#
# (22,55,.,.) =
#  0.01 *
#   2.1194
#
# (23,55,.,.) =
#  0.001 *
#   6.0043
#
# (24,55,.,.) =
#  0.001 *
#  -4.4594
#
# (25,55,.,.) =
#  0.001 *
#  -1.6251
#
# (26,55,.,.) =
#  0.001 *
#  -1.9474
#
# (27,55,.,.) =
#  0.001 *
#  -5.0087
#
# (28,55,.,.) =
#  0.001 *
#  -9.2621
#
# (29,55,.,.) =
#  0.01 *
#  -1.1818
#
# (30,55,.,.) =
#  0.01 *
#  -1.2985
#
# (31,55,.,.) =
#  0.01 *
#  -1.3138
#
# (32,55,.,.) =
#  0.01 *
#  -1.2360
#
# (33,55,.,.) =
#  0.01 *
#   3.4424
#
# (34,55,.,.) =
#  0.01 *
#   7.6050
#
# (35,55,.,.) =
#  0.01 *
#  -9.0759
#
# (36,55,.,.) =
#   0.1600
#
# (37,55,.,.) =
#   0.1470
#
# (38,55,.,.) =
#  0.01 *
#  -5.4321
#
# (39,55,.,.) =
#  0.01 *
#  -6.3049
#
# (40,55,.,.) =
#  0.01 *
#  -3.2135
#
# (41,55,.,.) =
#  0.01 *
#  -2.7161
#
# (42,55,.,.) =
#  0.01 *
#  -3.2562
#
# (43,55,.,.) =
#  0.01 *
#  -2.4857
#
# (44,55,.,.) =
#  0.01 *
#  -1.9348
#
# (45,55,.,.) =
#  0.01 *
#  -1.7593
#
# (46,55,.,.) =
#  0.01 *
#  -1.7151
#
# (47,55,.,.) =
#  0.01 *
#  -1.7029
#
# (48,55,.,.) =
#  0.01 *
#  -2.1683
#
# (49,55,.,.) =
#  0.01 *
#   1.0590
#
# (50,55,.,.) =
#  0.01 *
#   1.1734
#
# (51,55,.,.) =
#  0.01 *
#   1.3268
#
# (52,55,.,.) =
#  0.01 *
#   1.1803
#
# (53,55,.,.) =
#  0.01 *
#   1.3168
#
# (54,55,.,.) =
#  0.01 *
#   1.3687
#
# (55,55,.,.) =
#  0.001 *
#   5.4932
#
# (56,55,.,.) =
#  0.001 *
#  -1.6947
#
# (57,55,.,.) =
#  0.001 *
#  -1.9045
#
# (58,55,.,.) =
#  0.001 *
#  -1.4238
#
# (59,55,.,.) =
#  0.001 *
#  -6.2370
#
# (60,55,.,.) =
#  0.01 *
#  -1.2238
#
# (61,55,.,.) =
#  0.01 *
#  -1.4236
#
# (62,55,.,.) =
#  0.01 *
#  -1.4038
#
# (63,55,.,.) =
#  0.01 *
#  -1.3191
#
# (64,55,.,.) =
#  0.01 *
#  -1.4771
#
# (1,56,.,.) =
#  0.001 *
#   6.7673
#
# (2,56,.,.) =
#  0.001 *
#   8.7509
#
# (3,56,.,.) =
#  0.01 *
#   1.2314
#
# (4,56,.,.) =
#  0.01 *
#   1.1742
#
# (5,56,.,.) =
#  0.001 *
#   8.3847
#
# (6,56,.,.) =
#  0.001 *
#   2.8877
#
# (7,56,.,.) =
#  0.001 *
#   4.9553
#
# (8,56,.,.) =
#  0.001 *
#   3.4447
#
# (9,56,.,.) =
#  0.001 *
#   3.1128
#
# (10,56,.,.) =
#  0.0001 *
#  -9.8896
#
# (11,56,.,.) =
#  0.001 *
#  -5.1422
#
# (12,56,.,.) =
#  0.001 *
#  -7.9117
#
# (13,56,.,.) =
#  0.001 *
#  -9.7733
#
# (14,56,.,.) =
#  0.01 *
#  -1.1452
#
# (15,56,.,.) =
#  0.01 *
#  -1.2115
#
# (16,56,.,.) =
#  0.01 *
#  -1.5076
#
# (17,56,.,.) =
#  0.01 *
#   1.3321
#
# (18,56,.,.) =
#  0.01 *
#   1.1337
#
# (19,56,.,.) =
#  0.01 *
#   1.2009
#
# (20,56,.,.) =
#  0.01 *
#   1.1604
#
# (21,56,.,.) =
#  0.01 *
#   1.2138
#
# (22,56,.,.) =
#  0.001 *
#   9.5215
#
# (23,56,.,.) =
#  0.001 *
#   3.0861
#
# (24,56,.,.) =
#  0.001 *
#  -5.8022
#
# (25,56,.,.) =
#  0.001 *
#  -6.5536
#
# (26,56,.,.) =
#  0.001 *
#  -6.3362
#
# (27,56,.,.) =
#  0.001 *
#  -6.0844
#
# (28,56,.,.) =
#  0.001 *
#  -6.8016
#
# (29,56,.,.) =
#  0.001 *
#  -8.2550
#
# (30,56,.,.) =
#  0.001 *
#  -9.5596
#
# (31,56,.,.) =
#  0.01 *
#  -1.0429
#
# (32,56,.,.) =
#  0.01 *
#  -1.3298
#
# (33,56,.,.) =
#  0.01 *
#  -1.0010
#
# (34,56,.,.) =
#  0.01 *
#   3.5950
#
# (35,56,.,.) =
#   0.1475
#
# (36,56,.,.) =
#  0.01 *
#  -7.2266
#
# (37,56,.,.) =
#   0.1409
#
# (38,56,.,.) =
#  0.001 *
#  -7.3166
#
# (39,56,.,.) =
#  -0.1085
#
# (40,56,.,.) =
#  0.01 *
#  -1.8738
#
# (41,56,.,.) =
#  0.001 *
#   2.6970
#
# (42,56,.,.) =
#  0.001 *
#  -8.3313
#
# (43,56,.,.) =
#  0.01 *
#  -1.5099
#
# (44,56,.,.) =
#  0.01 *
#  -1.6525
#
# (45,56,.,.) =
#  0.01 *
#  -1.6434
#
# (46,56,.,.) =
#  0.01 *
#  -1.6220
#
# (47,56,.,.) =
#  0.01 *
#  -1.5747
#
# (48,56,.,.) =
#  0.01 *
#  -2.1637
#
# (49,56,.,.) =
#  0.01 *
#   1.1894
#
# (50,56,.,.) =
#  0.01 *
#   1.0017
#
# (51,56,.,.) =
#  0.001 *
#   9.8724
#
# (52,56,.,.) =
#  0.001 *
#   8.8196
#
# (53,56,.,.) =
#  0.01 *
#   1.6479
#
# (54,56,.,.) =
#  0.01 *
#   1.1131
#
# (55,56,.,.) =
#  0.001 *
#   2.5959
#
# (56,56,.,.) =
#  0.001 *
#  -1.0080
#
# (57,56,.,.) =
#  0.001 *
#  -3.0403
#
# (58,56,.,.) =
#  0.001 *
#  -6.3591
#
# (59,56,.,.) =
#  0.001 *
#  -7.1678
#
# (60,56,.,.) =
#  0.001 *
#  -7.7782
#
# (61,56,.,.) =
#  0.001 *
#  -9.2697
#
# (62,56,.,.) =
#  0.01 *
#  -1.0742
#
# (63,56,.,.) =
#  0.01 *
#  -1.1360
#
# (64,56,.,.) =
#  0.01 *
#  -1.4008
#
# (1,57,.,.) =
#  0.01 *
#   1.0643
#
# (2,57,.,.) =
#  0.001 *
#   9.8038
#
# (3,57,.,.) =
#  0.001 *
#   5.5046
#
# (4,57,.,.) =
#  0.01 *
#   1.2939
#
# (5,57,.,.) =
#  0.001 *
#   6.8130
#
# (6,57,.,.) =
#  0.001 *
#   3.3951
#
# (7,57,.,.) =
#  0.001 *
#   3.1376
#
# (8,57,.,.) =
#  0.001 *
#   2.1362
#
# (9,57,.,.) =
#  0.001 *
#   2.2697
#
# (10,57,.,.) =
#  0.001 *
#  -3.2578
#
# (11,57,.,.) =
#  0.001 *
#  -7.3318
#
# (12,57,.,.) =
#  0.001 *
#  -8.9798
#
# (13,57,.,.) =
#  0.001 *
#  -9.3536
#
# (14,57,.,.) =
#  0.001 *
#  -9.8038
#
# (15,57,.,.) =
#  0.01 *
#  -1.0101
#
# (16,57,.,.) =
#  0.001 *
#  -7.9346
#
# (17,57,.,.) =
#  0.001 *
#   6.3705
#
# (18,57,.,.) =
#  0.01 *
#   1.1520
#
# (19,57,.,.) =
#  0.01 *
#   1.1360
#
# (20,57,.,.) =
#  0.01 *
#   1.0292
#
# (21,57,.,.) =
#  0.001 *
#   5.3329
#
# (22,57,.,.) =
#  0.0001 *
#   9.6178
#
# (23,57,.,.) =
#  0.001 *
#   4.2725
#
# (24,57,.,.) =
#  0.001 *
#   2.8019
#
# (25,57,.,.) =
#  0.001 *
#   1.6203
#
# (26,57,.,.) =
#  0.001 *
#  -1.2331
#
# (27,57,.,.) =
#  0.001 *
#  -4.1504
#
# (28,57,.,.) =
#  0.001 *
#  -7.0572
#
# (29,57,.,.) =
#  0.001 *
#  -9.0485
#
# (30,57,.,.) =
#  0.01 *
#  -1.0239
#
# (31,57,.,.) =
#  0.01 *
#  -1.0948
#
# (32,57,.,.) =
#  0.01 *
#  -1.1887
#
# (33,57,.,.) =
#  0.001 *
#   4.0855
#
# (34,57,.,.) =
#  0.001 *
#   4.5128
#
# (35,57,.,.) =
#  0.001 *
#   7.1335
#
# (36,57,.,.) =
#  0.001 *
#   6.1684
#
# (37,57,.,.) =
#  0.01 *
#   1.0132
#
# (38,57,.,.) =
#  0.01 *
#   1.0773
#
# (39,57,.,.) =
#  0.001 *
#   3.7727
#
# (40,57,.,.) =
#  0.001 *
#   4.1656
#
# (41,57,.,.) =
#  0.001 *
#   2.9602
#
# (42,57,.,.) =
#  0.001 *
#  -2.5616
#
# (43,57,.,.) =
#  0.001 *
#  -6.4583
#
# (44,57,.,.) =
#  0.001 *
#  -8.4915
#
# (45,57,.,.) =
#  0.001 *
#  -9.5062
#
# (46,57,.,.) =
#  0.001 *
#  -9.8267
#
# (47,57,.,.) =
#  0.001 *
#  -9.6512
#
# (48,57,.,.) =
#  0.001 *
#  -7.2517
#
# (49,57,.,.) =
#   0.1377
#
# (50,57,.,.) =
#  -0.2296
#
# (51,57,.,.) =
#  0.001 *
#   6.3744
#
# (52,57,.,.) =
#  0.01 *
#   9.2651
#
# (53,57,.,.) =
#  0.01 *
#   3.0518
#
# (54,57,.,.) =
#  0.01 *
#  -1.9958
#
# (55,57,.,.) =
#  0.01 *
#  -3.2745
#
# (56,57,.,.) =
#  0.0001 *
#  -4.7016
#
# (57,57,.,.) =
#  0.01 *
#   2.9709
#
# (58,57,.,.) =
#  0.01 *
#   3.9490
#
# (59,57,.,.) =
#  0.01 *
#   1.3908
#
# (60,57,.,.) =
#  0.001 *
#  -8.6441
#
# (61,57,.,.) =
#  0.01 *
#  -1.3573
#
# (62,57,.,.) =
#  0.01 *
#  -1.3054
#
# (63,57,.,.) =
#  0.01 *
#  -1.2238
#
# (64,57,.,.) =
#  0.01 *
#  -2.0126
#
# (1,58,.,.) =
#  0.01 *
#  -1.0094
#
# (2,58,.,.) =
#  0.001 *
#  -8.3313
#
# (3,58,.,.) =
#  0.001 *
#  -3.9825
#
# (4,58,.,.) =
#  0.001 *
#   5.9471
#
# (5,58,.,.) =
#  0.001 *
#   4.0665
#
# (6,58,.,.) =
#  0.001 *
#   6.1111
#
# (7,58,.,.) =
#  0.01 *
#   1.4191
#
# (8,58,.,.) =
#  0.01 *
#   1.0963
#
# (9,58,.,.) =
#  0.001 *
#   5.4550
#
# (10,58,.,.) =
#  0.001 *
#   3.6850
#
# (11,58,.,.) =
#  0.001 *
#   3.2921
#
# (12,58,.,.) =
#  0.0001 *
#   6.9523
#
# (13,58,.,.) =
#  0.001 *
#  -3.5419
#
# (14,58,.,.) =
#  0.001 *
#  -7.3814
#
# (15,58,.,.) =
#  0.001 *
#  -9.8724
#
# (16,58,.,.) =
#  0.01 *
#  -1.1307
#
# (17,58,.,.) =
#  0.01 *
#   1.4893
#
# (18,58,.,.) =
#  0.001 *
#   8.3313
#
# (19,58,.,.) =
#  0.001 *
#   6.2714
#
# (20,58,.,.) =
#  0.001 *
#   3.0441
#
# (21,58,.,.) =
#  0.001 *
#   2.3079
#
# (22,58,.,.) =
#  0.0001 *
#   9.9945
#
# (23,58,.,.) =
#  0.001 *
#   6.8130
#
# (24,58,.,.) =
#  0.001 *
#   7.8278
#
# (25,58,.,.) =
#  0.001 *
#   3.7460
#
# (26,58,.,.) =
#  0.001 *
#  -2.5883
#
# (27,58,.,.) =
#  0.001 *
#  -7.6408
#
# (28,58,.,.) =
#  0.01 *
#  -1.0017
#
# (29,58,.,.) =
#  0.01 *
#  -1.0262
#
# (30,58,.,.) =
#  0.001 *
#  -9.9106
#
# (31,58,.,.) =
#  0.001 *
#  -9.0408
#
# (32,58,.,.) =
#  0.001 *
#  -4.7836
#
# (33,58,.,.) =
#  0.001 *
#  -1.7319
#
# (34,58,.,.) =
#  0.001 *
#  -1.2360
#
# (35,58,.,.) =
#  1e-05 *
#  -1.0610
#
# (36,58,.,.) =
#  0.0001 *
#  -2.2042
#
# (37,58,.,.) =
#  0.001 *
#   8.3466
#
# (38,58,.,.) =
#  0.001 *
#   2.1305
#
# (39,58,.,.) =
#  0.001 *
#   7.9956
#
# (40,58,.,.) =
#  0.001 *
#   7.7400
#
# (41,58,.,.) =
#  0.001 *
#   4.5090
#
# (42,58,.,.) =
#  0.001 *
#   2.7599
#
# (43,58,.,.) =
#  0.001 *
#   1.9894
#
# (44,58,.,.) =
#  0.0001 *
#  -2.2995
#
# (45,58,.,.) =
#  0.001 *
#  -3.7651
#
# (46,58,.,.) =
#  0.001 *
#  -7.1907
#
# (47,58,.,.) =
#  0.001 *
#  -9.4223
#
# (48,58,.,.) =
#  0.01 *
#  -1.1642
#
# (49,58,.,.) =
#  -0.1511
#
# (50,58,.,.) =
#   0.1741
#
# (51,58,.,.) =
#   0.1667
#
# (52,58,.,.) =
#  0.01 *
#   9.0637
#
# (53,58,.,.) =
#  -0.1803
#
# (54,58,.,.) =
#  0.01 *
#  -4.4525
#
# (55,58,.,.) =
#  0.001 *
#   1.4153
#
# (56,58,.,.) =
#  0.01 *
#   2.2522
#
# (57,58,.,.) =
#  0.001 *
#   9.5291
#
# (58,58,.,.) =
#  0.01 *
#  -2.3972
#
# (59,58,.,.) =
#  0.01 *
#  -3.3234
#
# (60,58,.,.) =
#  0.01 *
#  -1.8707
#
# (61,58,.,.) =
#  0.001 *
#  -8.3847
#
# (62,58,.,.) =
#  0.001 *
#  -5.3482
#
# (63,58,.,.) =
#  0.001 *
#  -4.7531
#
# (64,58,.,.) =
#  0.001 *
#   5.5389
#
# (1,59,.,.) =
#  0.01 *
#   1.9455
#
# (2,59,.,.) =
#  0.01 *
#   2.0111
#
# (3,59,.,.) =
#  0.01 *
#   1.9577
#
# (4,59,.,.) =
#  0.01 *
#   1.5129
#
# (5,59,.,.) =
#  0.01 *
#   1.6617
#
# (6,59,.,.) =
#  0.01 *
#   1.3794
#
# (7,59,.,.) =
#  0.001 *
#   3.3989
#
# (8,59,.,.) =
#  0.001 *
#  -1.2245
#
# (9,59,.,.) =
#  0.001 *
#  -4.2419
#
# (10,59,.,.) =
#  0.001 *
#  -7.2861
#
# (11,59,.,.) =
#  0.001 *
#  -9.8038
#
# (12,59,.,.) =
#  0.01 *
#  -1.2787
#
# (13,59,.,.) =
#  0.01 *
#  -1.6068
#
# (14,59,.,.) =
#  0.01 *
#  -1.7548
#
# (15,59,.,.) =
#  0.01 *
#  -1.7960
#
# (16,59,.,.) =
#  0.01 *
#  -2.1362
#
# (17,59,.,.) =
#  0.01 *
#  -7.4341
#
# (18,59,.,.) =
#  0.01 *
#  -8.4351
#
# (19,59,.,.) =
#   0.1061
#
# (20,59,.,.) =
#  0.01 *
#   2.4048
#
# (21,59,.,.) =
#   0.1919
#
# (22,59,.,.) =
#   0.1373
#
# (23,59,.,.) =
#  0.01 *
#  -6.0028
#
# (24,59,.,.) =
#  0.01 *
#  -4.3762
#
# (25,59,.,.) =
#  0.01 *
#  -2.5894
#
# (26,59,.,.) =
#  0.01 *
#  -2.3346
#
# (27,59,.,.) =
#  0.01 *
#  -2.3926
#
# (28,59,.,.) =
#  0.01 *
#  -2.4033
#
# (29,59,.,.) =
#  0.01 *
#  -2.3560
#
# (30,59,.,.) =
#  0.01 *
#  -2.2964
#
# (31,59,.,.) =
#  0.01 *
#  -2.2186
#
# (32,59,.,.) =
#  0.01 *
#  -3.0884
#
# (33,59,.,.) =
#  0.01 *
#   1.6769
#
# (34,59,.,.) =
#  0.01 *
#   1.8600
#
# (35,59,.,.) =
#  0.01 *
#   2.0569
#
# (36,59,.,.) =
#  0.01 *
#   2.1301
#
# (37,59,.,.) =
#  0.01 *
#   2.0309
#
# (38,59,.,.) =
#  0.01 *
#   1.3359
#
# (39,59,.,.) =
#  0.001 *
#   2.6550
#
# (40,59,.,.) =
#  0.001 *
#  -7.5645
#
# (41,59,.,.) =
#  0.01 *
#  -1.1337
#
# (42,59,.,.) =
#  0.001 *
#  -9.7733
#
# (43,59,.,.) =
#  0.001 *
#  -9.4833
#
# (44,59,.,.) =
#  0.01 *
#  -1.1353
#
# (45,59,.,.) =
#  0.01 *
#  -1.3855
#
# (46,59,.,.) =
#  0.01 *
#  -1.5549
#
# (47,59,.,.) =
#  0.01 *
#  -1.6068
#
# (48,59,.,.) =
#  0.01 *
#  -1.8555
#
# (49,59,.,.) =
#  0.01 *
#   1.5671
#
# (50,59,.,.) =
#  0.01 *
#   1.5038
#
# (51,59,.,.) =
#  0.01 *
#   1.5572
#
# (52,59,.,.) =
#  0.01 *
#   1.4267
#
# (53,59,.,.) =
#  0.01 *
#   1.2840
#
# (54,59,.,.) =
#  0.01 *
#   1.1208
#
# (55,59,.,.) =
#  0.001 *
#   3.2654
#
# (56,59,.,.) =
#  0.001 *
#   2.0752
#
# (57,59,.,.) =
#  0.001 *
#   1.5507
#
# (58,59,.,.) =
#  0.001 *
#  -3.0670
#
# (59,59,.,.) =
#  0.001 *
#  -5.7831
#
# (60,59,.,.) =
#  0.001 *
#  -8.4915
#
# (61,59,.,.) =
#  0.01 *
#  -1.3458
#
# (62,59,.,.) =
#  0.01 *
#  -1.7487
#
# (63,59,.,.) =
#  0.01 *
#  -1.9547
#
# (64,59,.,.) =
#  0.01 *
#  -2.3514
#
# (1,60,.,.) =
#  0.001 *
#   4.6921
#
# (2,60,.,.) =
#  0.001 *
#   5.6152
#
# (3,60,.,.) =
#  0.001 *
#   9.3155
#
# (4,60,.,.) =
#  0.01 *
#   1.3924
#
# (5,60,.,.) =
#  0.01 *
#   1.7792
#
# (6,60,.,.) =
#  0.01 *
#   1.8402
#
# (7,60,.,.) =
#  0.01 *
#   1.7166
#
# (8,60,.,.) =
#  0.001 *
#   9.0485
#
# (9,60,.,.) =
#  0.001 *
#  -2.6913
#
# (10,60,.,.) =
#  0.001 *
#  -9.9182
#
# (11,60,.,.) =
#  0.01 *
#  -1.3237
#
# (12,60,.,.) =
#  0.01 *
#  -1.4488
#
# (13,60,.,.) =
#  0.01 *
#  -1.4130
#
# (14,60,.,.) =
#  0.01 *
#  -1.3229
#
# (15,60,.,.) =
#  0.01 *
#  -1.2520
#
# (16,60,.,.) =
#  0.01 *
#  -1.5793
#
# (17,60,.,.) =
#  0.01 *
#  -9.7961
#
# (18,60,.,.) =
#  -0.1027
#
# (19,60,.,.) =
#  -0.1390
#
# (20,60,.,.) =
#  -0.1663
#
# (21,60,.,.) =
#  0.01 *
#   3.3325
#
# (22,60,.,.) =
#   0.1732
#
# (23,60,.,.) =
#   0.1024
#
# (24,60,.,.) =
#  0.01 *
#   3.8177
#
# (25,60,.,.) =
#  0.01 *
#   2.3026
#
# (26,60,.,.) =
#  0.01 *
#   3.4943
#
# (27,60,.,.) =
#  0.01 *
#   3.7109
#
# (28,60,.,.) =
#  0.01 *
#   2.9648
#
# (29,60,.,.) =
#  0.01 *
#   1.8784
#
# (30,60,.,.) =
#  0.001 *
#   9.4223
#
# (31,60,.,.) =
#  0.001 *
#   3.2234
#
# (32,60,.,.) =
#  0.001 *
#   2.9736
#
# (33,60,.,.) =
#  0.001 *
#   6.1378
#
# (34,60,.,.) =
#  0.001 *
#   7.3128
#
# (35,60,.,.) =
#  0.01 *
#   1.1246
#
# (36,60,.,.) =
#  0.01 *
#   1.4908
#
# (37,60,.,.) =
#  0.01 *
#   2.1927
#
# (38,60,.,.) =
#  0.01 *
#   2.2308
#
# (39,60,.,.) =
#  0.01 *
#   1.1490
#
# (40,60,.,.) =
#  0.001 *
#   1.8311
#
# (41,60,.,.) =
#  0.001 *
#  -6.2714
#
# (42,60,.,.) =
#  0.01 *
#  -1.2405
#
# (43,60,.,.) =
#  0.01 *
#  -1.4778
#
# (44,60,.,.) =
#  0.01 *
#  -1.4305
#
# (45,60,.,.) =
#  0.01 *
#  -1.2993
#
# (46,60,.,.) =
#  0.01 *
#  -1.1749
#
# (47,60,.,.) =
#  0.01 *
#  -1.1169
#
# (48,60,.,.) =
#  0.01 *
#  -1.3405
#
# (49,60,.,.) =
#  0.01 *
#  -1.2909
#
# (50,60,.,.) =
#  0.01 *
#  -1.1642
#
# (51,60,.,.) =
#  0.001 *
#  -9.3231
#
# (52,60,.,.) =
#  0.001 *
#  -4.6158
#
# (53,60,.,.) =
#  0.001 *
#  -3.5057
#
# (54,60,.,.) =
#  0.0001 *
#  -8.5449
#
# (55,60,.,.) =
#  0.001 *
#   4.0398
#
# (56,60,.,.) =
#  0.001 *
#  -2.0123
#
# (57,60,.,.) =
#  0.001 *
#  -5.5046
#
# (58,60,.,.) =
#  0.001 *
#  -5.3787
#
# (59,60,.,.) =
#  0.0001 *
#   9.2363
#
# (60,60,.,.) =
#  0.01 *
#   1.0468
#
# (61,60,.,.) =
#  0.01 *
#   1.3077
#
# (62,60,.,.) =
#  0.001 *
#   9.8267
#
# (63,60,.,.) =
#  0.001 *
#   4.9934
#
# (64,60,.,.) =
#  0.01 *
#   1.2527
#
# (1,61,.,.) =
#  0.01 *
#   2.1469
#
# (2,61,.,.) =
#  0.01 *
#   2.1713
#
# (3,61,.,.) =
#  0.01 *
#   1.9821
#
# (4,61,.,.) =
#  0.01 *
#   1.5976
#
# (5,61,.,.) =
#  0.01 *
#   1.9394
#
# (6,61,.,.) =
#  0.01 *
#   1.6251
#
# (7,61,.,.) =
#  0.01 *
#   1.3885
#
# (8,61,.,.) =
#  0.001 *
#   6.1798
#
# (9,61,.,.) =
#  0.0001 *
#  -8.2254
#
# (10,61,.,.) =
#  0.001 *
#  -7.3814
#
# (11,61,.,.) =
#  0.01 *
#  -1.2962
#
# (12,61,.,.) =
#  0.01 *
#  -1.6312
#
# (13,61,.,.) =
#  0.01 *
#  -1.9165
#
# (14,61,.,.) =
#  0.01 *
#  -2.1835
#
# (15,61,.,.) =
#  0.01 *
#  -2.4033
#
# (16,61,.,.) =
#  0.01 *
#  -3.2349
#
# (17,61,.,.) =
#   0.2052
#
# (18,61,.,.) =
#   0.2129
#
# (19,61,.,.) =
#   0.2211
#
# (20,61,.,.) =
#   0.1459
#
# (21,61,.,.) =
#  -0.1332
#
# (22,61,.,.) =
#  -0.1412
#
# (23,61,.,.) =
#  -0.1299
#
# (24,61,.,.) =
#  0.01 *
#  -9.7412
#
# (25,61,.,.) =
#  0.01 *
#  -6.7444
#
# (26,61,.,.) =
#  0.01 *
#  -4.9988
#
# (27,61,.,.) =
#  0.01 *
#  -3.9581
#
# (28,61,.,.) =
#  0.01 *
#  -3.1555
#
# (29,61,.,.) =
#  0.01 *
#  -2.5665
#
# (30,61,.,.) =
#  0.01 *
#  -2.2278
#
# (31,61,.,.) =
#  0.01 *
#  -2.0218
#
# (32,61,.,.) =
#  0.01 *
#  -2.6428
#
# (33,61,.,.) =
#  0.01 *
#   1.3191
#
# (34,61,.,.) =
#  0.01 *
#   1.3397
#
# (35,61,.,.) =
#  0.01 *
#   1.3725
#
# (36,61,.,.) =
#  0.01 *
#   1.6937
#
# (37,61,.,.) =
#  0.01 *
#   1.7654
#
# (38,61,.,.) =
#  0.01 *
#   1.8753
#
# (39,61,.,.) =
#  0.01 *
#   1.7029
#
# (40,61,.,.) =
#  0.01 *
#   1.2032
#
# (41,61,.,.) =
#  0.001 *
#   8.0719
#
# (42,61,.,.) =
#  0.0001 *
#  -6.2418
#
# (43,61,.,.) =
#  0.001 *
#  -8.3466
#
# (44,61,.,.) =
#  0.01 *
#  -1.4717
#
# (45,61,.,.) =
#  0.01 *
#  -2.0142
#
# (46,61,.,.) =
#  0.01 *
#  -2.3956
#
# (47,61,.,.) =
#  0.01 *
#  -2.6657
#
# (48,61,.,.) =
#  0.01 *
#  -3.6255
#
# (49,61,.,.) =
#  0.01 *
#   2.8336
#
# (50,61,.,.) =
#  0.01 *
#   3.2196
#
# (51,61,.,.) =
#  0.01 *
#   3.1860
#
# (52,61,.,.) =
#  0.01 *
#   3.5278
#
# (53,61,.,.) =
#  0.01 *
#   4.1595
#
# (54,61,.,.) =
#  0.01 *
#   3.3295
#
# (55,61,.,.) =
#  0.001 *
#   5.2681
#
# (56,61,.,.) =
#  0.01 *
#  -1.4198
#
# (57,61,.,.) =
#  0.01 *
#  -2.3239
#
# (58,61,.,.) =
#  0.01 *
#  -2.6031
#
# (59,61,.,.) =
#  0.01 *
#  -2.7817
#
# (60,61,.,.) =
#  0.01 *
#  -2.7634
#
# (61,61,.,.) =
#  0.01 *
#  -2.4826
#
# (62,61,.,.) =
#  0.01 *
#  -2.1698
#
# (63,61,.,.) =
#  0.01 *
#  -1.9043
#
# (64,61,.,.) =
#  0.01 *
#  -2.2964
#
# (1,62,.,.) =
#  -0.1733
#
# (2,62,.,.) =
#  -0.1725
#
# (3,62,.,.) =
#  -0.1857
#
# (4,62,.,.) =
#  -0.1877
#
# (5,62,.,.) =
#  -0.1154
#
# (6,62,.,.) =
#  0.001 *
#   2.1133
#
# (7,62,.,.) =
#   0.1262
#
# (8,62,.,.) =
#   0.1709
#
# (9,62,.,.) =
#   0.1539
#
# (10,62,.,.) =
#   0.1190
#
# (11,62,.,.) =
#  0.01 *
#   8.1604
#
# (12,62,.,.) =
#  0.01 *
#   5.2979
#
# (13,62,.,.) =
#  0.01 *
#   3.9734
#
# (14,62,.,.) =
#  0.01 *
#   3.3447
#
# (15,62,.,.) =
#  0.01 *
#   2.8564
#
# (16,62,.,.) =
#  0.01 *
#   2.6138
#
# (17,62,.,.) =
#  0.01 *
#   1.2779
#
# (18,62,.,.) =
#  0.01 *
#   1.3382
#
# (19,62,.,.) =
#  0.01 *
#   1.1909
#
# (20,62,.,.) =
#  0.01 *
#   1.2268
#
# (21,62,.,.) =
#  0.01 *
#   1.4732
#
# (22,62,.,.) =
#  0.01 *
#   1.0086
#
# (23,62,.,.) =
#  0.001 *
#   5.0392
#
# (24,62,.,.) =
#  1e-06 *
#  -8.5235
#
# (25,62,.,.) =
#  0.001 *
#  -5.6496
#
# (26,62,.,.) =
#  0.001 *
#  -8.6441
#
# (27,62,.,.) =
#  0.01 *
#  -1.0239
#
# (28,62,.,.) =
#  0.01 *
#  -1.0872
#
# (29,62,.,.) =
#  0.01 *
#  -1.1032
#
# (30,62,.,.) =
#  0.01 *
#  -1.0704
#
# (31,62,.,.) =
#  0.01 *
#  -1.0223
#
# (32,62,.,.) =
#  0.01 *
#  -1.2848
#
# (33,62,.,.) =
#  0.001 *
#  -7.5455
#
# (34,62,.,.) =
#  0.001 *
#  -7.3090
#
# (35,62,.,.) =
#  0.001 *
#  -6.9809
#
# (36,62,.,.) =
#  0.001 *
#  -7.1869
#
# (37,62,.,.) =
#  0.001 *
#  -7.7133
#
# (38,62,.,.) =
#  0.01 *
#  -1.1398
#
# (39,62,.,.) =
#  0.001 *
#  -8.9569
#
# (40,62,.,.) =
#  0.001 *
#  -7.0343
#
# (41,62,.,.) =
#  0.001 *
#  -5.9853
#
# (42,62,.,.) =
#  0.001 *
#  -2.1420
#
# (43,62,.,.) =
#  0.001 *
#   2.6283
#
# (44,62,.,.) =
#  0.001 *
#   8.0795
#
# (45,62,.,.) =
#  0.01 *
#   1.2337
#
# (46,62,.,.) =
#  0.01 *
#   1.4343
#
# (47,62,.,.) =
#  0.01 *
#   1.3992
#
# (48,62,.,.) =
#  0.01 *
#   2.0996
#
# (49,62,.,.) =
#  0.01 *
#   1.0460
#
# (50,62,.,.) =
#  0.01 *
#   1.0849
#
# (51,62,.,.) =
#  0.01 *
#   1.0590
#
# (52,62,.,.) =
#  0.01 *
#   1.3115
#
# (53,62,.,.) =
#  0.01 *
#   1.4236
#
# (54,62,.,.) =
#  0.01 *
#   1.0612
#
# (55,62,.,.) =
#  0.001 *
#   6.6452
#
# (56,62,.,.) =
#  0.001 *
#   1.1768
#
# (57,62,.,.) =
#  0.001 *
#  -5.6000
#
# (58,62,.,.) =
#  0.001 *
#  -8.5678
#
# (59,62,.,.) =
#  0.001 *
#  -9.8648
#
# (60,62,.,.) =
#  0.01 *
#  -1.1017
#
# (61,62,.,.) =
#  0.01 *
#  -1.0704
#
# (62,62,.,.) =
#  0.01 *
#  -1.0262
#
# (63,62,.,.) =
#  0.001 *
#  -9.5062
#
# (64,62,.,.) =
#  0.01 *
#  -1.2222
#
# (1,63,.,.) =
#  0.001 *
#   6.8817
#
# (2,63,.,.) =
#  0.001 *
#   8.1940
#
# (3,63,.,.) =
#  0.01 *
#   1.1360
#
# (4,63,.,.) =
#  0.01 *
#   1.2733
#
# (5,63,.,.) =
#  0.001 *
#   9.9945
#
# (6,63,.,.) =
#  0.001 *
#   8.7051
#
# (7,63,.,.) =
#  0.001 *
#   2.2068
#
# (8,63,.,.) =
#  0.001 *
#   3.2806
#
# (9,63,.,.) =
#  0.001 *
#   4.4823
#
# (10,63,.,.) =
#  0.001 *
#  -1.2856
#
# (11,63,.,.) =
#  0.001 *
#  -7.3051
#
# (12,63,.,.) =
#  0.01 *
#  -1.1086
#
# (13,63,.,.) =
#  0.01 *
#  -1.1818
#
# (14,63,.,.) =
#  0.01 *
#  -1.2474
#
# (15,63,.,.) =
#  0.01 *
#  -1.2566
#
# (16,63,.,.) =
#  0.01 *
#  -1.1345
#
# (17,63,.,.) =
#  0.001 *
#   7.6981
#
# (18,63,.,.) =
#  0.001 *
#   7.9803
#
# (19,63,.,.) =
#  0.001 *
#   8.0338
#
# (20,63,.,.) =
#  0.01 *
#   1.0399
#
# (21,63,.,.) =
#  0.001 *
#   8.6594
#
# (22,63,.,.) =
#  0.001 *
#   8.6975
#
# (23,63,.,.) =
#  0.001 *
#   8.7585
#
# (24,63,.,.) =
#  0.001 *
#   2.0275
#
# (25,63,.,.) =
#  0.0001 *
#   5.1165
#
# (26,63,.,.) =
#  0.001 *
#  -2.1000
#
# (27,63,.,.) =
#  0.001 *
#  -6.0883
#
# (28,63,.,.) =
#  0.001 *
#  -9.3231
#
# (29,63,.,.) =
#  0.01 *
#  -1.1452
#
# (30,63,.,.) =
#  0.01 *
#  -1.2093
#
# (31,63,.,.) =
#  0.01 *
#  -1.2245
#
# (32,63,.,.) =
#  0.001 *
#  -9.4833
#
# (33,63,.,.) =
#  0.01 *
#   5.9113
#
# (34,63,.,.) =
#  0.01 *
#  -4.2206
#
# (35,63,.,.) =
#   0.1683
#
# (36,63,.,.) =
#   0.1803
#
# (37,63,.,.) =
#  -0.1026
#
# (38,63,.,.) =
#  0.01 *
#  -7.7942
#
# (39,63,.,.) =
#  0.001 *
#   5.0240
#
# (40,63,.,.) =
#  0.001 *
#  -6.5155
#
# (41,63,.,.) =
#  0.01 *
#  -4.0131
#
# (42,63,.,.) =
#  0.01 *
#  -5.1941
#
# (43,63,.,.) =
#  0.01 *
#  -3.9215
#
# (44,63,.,.) =
#  0.01 *
#  -2.4979
#
# (45,63,.,.) =
#  0.01 *
#  -1.3893
#
# (46,63,.,.) =
#  0.001 *
#  -8.8120
#
# (47,63,.,.) =
#  0.001 *
#  -7.4539
#
# (48,63,.,.) =
#  0.001 *
#   2.7599
#
# (49,63,.,.) =
#  0.001 *
#   4.5662
#
# (50,63,.,.) =
#  0.001 *
#   5.1041
#
# (51,63,.,.) =
#  0.001 *
#   6.0883
#
# (52,63,.,.) =
#  0.001 *
#   5.9547
#
# (53,63,.,.) =
#  0.001 *
#   9.6207
#
# (54,63,.,.) =
#  0.01 *
#   1.2451
#
# (55,63,.,.) =
#  0.01 *
#   1.2672
#
# (56,63,.,.) =
#  0.001 *
#   8.4991
#
# (57,63,.,.) =
#  0.001 *
#   6.3095
#
# (58,63,.,.) =
#  0.0001 *
#   4.0627
#
# (59,63,.,.) =
#  0.001 *
#  -8.1787
#
# (60,63,.,.) =
#  0.01 *
#  -1.2291
#
# (61,63,.,.) =
#  0.01 *
#  -1.3245
#
# (62,63,.,.) =
#  0.01 *
#  -1.3214
#
# (63,63,.,.) =
#  0.01 *
#  -1.2901
#
# (64,63,.,.) =
#  0.01 *
#  -1.1780
#
# (1,64,.,.) =
#  0.001 *
#   9.8724
#
# (2,64,.,.) =
#  0.01 *
#   1.1292
#
# (3,64,.,.) =
#  0.01 *
#   1.6052
#
# (4,64,.,.) =
#  0.01 *
#   1.9608
#
# (5,64,.,.) =
#  0.01 *
#   1.7700
#
# (6,64,.,.) =
#  0.01 *
#   1.2573
#
# (7,64,.,.) =
#  0.01 *
#   1.2032
#
# (8,64,.,.) =
#  0.001 *
#   8.1329
#
# (9,64,.,.) =
#  0.0001 *
#  -4.7112
#
# (10,64,.,.) =
#  0.001 *
#  -7.6332
#
# (11,64,.,.) =
#  0.01 *
#  -1.2367
#
# (12,64,.,.) =
#  0.01 *
#  -1.5717
#
# (13,64,.,.) =
#  0.01 *
#  -1.7426
#
# (14,64,.,.) =
#  0.01 *
#  -1.7395
#
# (15,64,.,.) =
#  0.01 *
#  -1.6830
#
# (16,64,.,.) =
#  0.01 *
#  -1.9562
#
# (17,64,.,.) =
#  -0.1353
#
# (18,64,.,.) =
#  -0.1549
#
# (19,64,.,.) =
#  -0.2151
#
# (20,64,.,.) =
#  0.01 *
#   9.0942
#
# (21,64,.,.) =
#   0.2074
#
# (22,64,.,.) =
#  0.01 *
#   2.0798
#
# (23,64,.,.) =
#  0.01 *
#   3.2104
#
# (24,64,.,.) =
#  0.01 *
#   9.7900
#
# (25,64,.,.) =
#  0.01 *
#   9.3201
#
# (26,64,.,.) =
#  0.01 *
#   4.9927
#
# (27,64,.,.) =
#  0.01 *
#   1.1559
#
# (28,64,.,.) =
#  0.01 *
#  -1.0712
#
# (29,64,.,.) =
#  0.01 *
#  -1.8082
#
# (30,64,.,.) =
#  0.01 *
#  -2.0721
#
# (31,64,.,.) =
#  0.01 *
#  -2.1530
#
# (32,64,.,.) =
#  0.01 *
#  -2.7374
#
# (33,64,.,.) =
#  0.01 *
#   1.2238
#
# (34,64,.,.) =
#  0.01 *
#   1.3268
#
# (35,64,.,.) =
#  0.01 *
#   1.4580
#
# ...
#  0.01 *
#   1.0918
#
# (59,64,.,.) =
#  0.001 *
#   9.4910
#
# (60,64,.,.) =
#  0.0001 *
#  -2.4509
#
# (61,64,.,.) =
#  0.001 *
#  -8.4229
#
# (62,64,.,.) =
#  0.01 *
#  -1.3763
#
# (63,64,.,.) =
#  0.01 *
#  -1.7303
#
# (64,64,.,.) =
#  0.01 *
#  -2.1439
# [ torch.cuda.HalfTensor{64,64,1,1} ]
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      12.8G      2.092      5.797       1.46         21        640: 100%|██████████| 1326/1326 [07:22<00:00,  3.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.96it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      13.2G      1.588      5.346      1.108         10        640: 100%|██████████| 1326/1326 [07:28<00:00,  2.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.01it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40      13.2G      1.518      4.948      1.075         28        640: 100%|██████████| 1326/1326 [07:19<00:00,  3.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.60it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      13.2G      1.507      4.554      1.089         12        640: 100%|██████████| 1326/1326 [07:18<00:00,  3.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.02it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      13.2G       1.49      4.335      1.093         19        640: 100%|██████████| 1326/1326 [07:20<00:00,  3.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.23it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      13.2G      1.479      4.227      1.098         63        640:  75%|███████▌  | 1001/1326 [05:28<01:32,  3.50it/s]2025-03-28 19:24:45,636 - hub_sdk.helpers.logger - ERROR - Internal server error.
# ERROR:hub_sdk.helpers.logger:Internal server error.
# 2025-03-28 19:24:45,638 - hub_sdk.helpers.logger - ERROR - Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# ERROR:hub_sdk.helpers.logger:Failed to start heartbeats: 'NoneType' object has no attribute 'json'
# Exception in thread Thread-8 (_start_heartbeats):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#        6/40      13.2G      1.479      4.227      1.098        103        640:  75%|███████▌  | 1001/1326 [05:28<01:32,  3.50it/s]    self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/hub_sdk/base/server_clients.py", line 176, in _start_heartbeats
#        6/40      13.2G      1.479      4.227      1.098        103        640:  76%|███████▌  | 1002/1326 [05:28<01:34,  3.42it/s]    raise e
#   File "/usr/local/lib/python3.11/dist-packages/hub_sdk/base/server_clients.py", line 164, in _start_heartbeats
#     res = self.post(endpoint, json=payload).json()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'json'
#        6/40      13.2G      1.479      4.214      1.097         12        640: 100%|██████████| 1326/1326 [07:23<00:00,  2.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.21it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      13.2G      1.472      4.124      1.099         11        640: 100%|██████████| 1326/1326 [07:26<00:00,  2.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.12it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      13.2G      1.465      4.046      1.102         24        640: 100%|██████████| 1326/1326 [07:30<00:00,  2.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:14<00:00,  4.34it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      13.2G       1.46       3.99      1.101         12        640: 100%|██████████| 1326/1326 [07:53<00:00,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.74it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      13.2G      1.453      3.942      1.103         25        640: 100%|██████████| 1326/1326 [07:45<00:00,  2.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:18<00:00,  3.38it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      13.2G       1.45      3.906      1.103          8        640: 100%|██████████| 1326/1326 [07:37<00:00,  2.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.72it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      13.2G       1.45      3.875      1.109         10        640: 100%|██████████| 1326/1326 [07:58<00:00,  2.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.73it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      13.3G      1.448      3.842      1.105         21        640: 100%|██████████| 1326/1326 [07:49<00:00,  2.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:20<00:00,  3.18it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      13.3G      1.444       3.81      1.107         32        640: 100%|██████████| 1326/1326 [08:03<00:00,  2.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.15it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      13.3G      1.442       3.79      1.109         15        640: 100%|██████████| 1326/1326 [08:15<00:00,  2.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:18<00:00,  3.49it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      12.7G      1.443      3.765      1.108         13        640: 100%|██████████| 1326/1326 [08:13<00:00,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:18<00:00,  3.39it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40        13G      1.439      3.744      1.108          9        640: 100%|██████████| 1326/1326 [08:04<00:00,  2.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:18<00:00,  3.43it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40        13G      1.437      3.725      1.108         17        640: 100%|██████████| 1326/1326 [08:08<00:00,  2.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:18<00:00,  3.47it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40        13G      1.435       3.71      1.109         18        640: 100%|██████████| 1326/1326 [08:13<00:00,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.07it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40        13G      1.434      3.694      1.108         29        640: 100%|██████████| 1326/1326 [08:01<00:00,  2.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:18<00:00,  3.38it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40        13G      1.435      3.687      1.109         21        640: 100%|██████████| 1326/1326 [08:05<00:00,  2.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:18<00:00,  3.45it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40        13G      1.431      3.674      1.109          7        640: 100%|██████████| 1326/1326 [07:55<00:00,  2.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.95it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40        13G      1.435      3.664      1.108         23        640: 100%|██████████| 1326/1326 [08:05<00:00,  2.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:18<00:00,  3.55it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40        13G      1.435      3.653      1.109         21        640: 100%|██████████| 1326/1326 [08:07<00:00,  2.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.82it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40        13G      1.435      3.649      1.108         28        640: 100%|██████████| 1326/1326 [08:26<00:00,  2.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.73it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40        13G      1.433      3.636      1.108         18        640: 100%|██████████| 1326/1326 [08:13<00:00,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.61it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40        13G      1.432      3.634      1.105         18        640: 100%|██████████| 1326/1326 [08:08<00:00,  2.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.58it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40        13G      1.434      3.621      1.106         20        640: 100%|██████████| 1326/1326 [07:53<00:00,  2.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:19<00:00,  3.36it/s]
#                    all       2020       8080          0          0          0          0
# Ultralytics HUB: Uploading checkpoint https://hub.ultralytics.com/models/cL8sk3M1vOoYjAV7WWRR
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      13.1G      1.433      3.616      1.109         23        640: 100%|██████████| 1326/1326 [07:59<00:00,  2.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.09it/s]
#                    all       2020       8080          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      13.1G      1.428      3.607      1.108         85        640:  82%|████████▏ | 1082/1326 [06:31<01:06,  3.65it/s]
